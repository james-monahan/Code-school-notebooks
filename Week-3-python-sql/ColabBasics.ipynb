# %% [markdown]
# <a href="https://colab.research.google.com/github/james-monahan/Code-school-notebooks/blob/main/Week-3-python-sql/ColabBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Crée un notebook vide sur Google colaboratory avec comme titre : "Notebook Prenom Nom"
#
# Rend le notebook accessible en commentaire pour toute personne disposant du lien
# Dans une cellule code affiche la version de Python
#
# Dans des cellules successives, vérifie la version du module Pandas, ensuite met Pandas à jour, enfin vérifie la nouvelle version
#
# Dans une cellule texte, écrit la formule mathématique présente sur cette image et l'équation de Boltzmann.
#
# Met le hardware accelerator de Google colab en GPU, fait un screenshot de cette modification, enregistre la dans ton Google drive, et enfin affiche l'image du screeshot dans une cellule grâce à son url drive
#
# Dans une cellule, affiche la vidéo Youtube suivante : 20 LUCKIEST PEOPLE CAUGHT ON CAMERA

# %%
# !python --version
# Out:
# Python 3.6.9

# %%
# !pip show pandas
# Out:
# Name: pandas
# Version: 1.0.5
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: None
# Author-email: None
# License: BSD
# Location: /usr/local/lib/python3.6/dist-packages
# Requires: pytz, python-dateutil, numpy
# Required-by: xarray, vega-datasets, statsmodels, sklearn-pandas, seaborn, pymc3, plotnine, pandas-profiling, pandas-gbq, pandas-datareader, mlxtend, mizani, holoviews, gspread-dataframe, google-colab, fix-yahoo-finance, fbprophet, fastai, cufflinks, cmdstanpy, altair

# %%
# !pip install --upgrade pandas
# Out:
# ...
#      |████████████████████████████████| 10.5MB 4.7MB/s
# ...
# ERROR: google-colab 1.0.0 has requirement pandas~=1.0.0; python_version >= "3.0", but you'll have pandas 1.1.2 which is incompatible.
# ...
#   Found existing installation: pandas 1.0.5
#     Uninstalling pandas-1.0.5:
#       Successfully uninstalled pandas-1.0.5
# ...

# %%
# !pip show pandas
# Out:
# Name: pandas
# Version: 1.1.2
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: None
# Author-email: None
# License: BSD
# Location: /usr/local/lib/python3.6/dist-packages
# Requires: numpy, pytz, python-dateutil
# Required-by: xarray, vega-datasets, statsmodels, sklearn-pandas, seaborn, pymc3, plotnine, pandas-profiling, pandas-gbq, pandas-datareader, mlxtend, mizani, holoviews, gspread-dataframe, google-colab, fix-yahoo-finance, fbprophet, fastai, cufflinks, cmdstanpy, altair

# %% [markdown]
# ###Helped by Mathpix (android)
#
#
# $$ 06, e ^ {4}\pi.\sqrt{7}\sin\pi,\phi\int _ {- 2} ^ {4} xdx, \ e ^ {- l} \ ln\ e $$
#
# $$ \frac {\partial f} {\partial t} + v \cdot \nabla_ {x} f = \int _ {\mathrm {R} ^ {3}} \int _ {\mathrm {S} ^ {2}} \left | v-v _ {*} \right | \left [f \left (v ^ {\prime} \right) f \left (v _ {*} ^ {\prime} \right) -f (v) f \left (v _ {*} \right) \right] d v _ {*} d \sigma, $$

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from IPython.display import Image

Image(filename='/content/drive/My Drive/GPU_screenshot.png')

# %%
from IPython.display import HTML

# Youtube
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/XZysgIslP2A" frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/XZysgIslP2A" frameborder="0" allowfullscreen></iframe>
