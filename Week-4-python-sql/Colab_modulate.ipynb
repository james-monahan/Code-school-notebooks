# %% [markdown]
# <a href="https://colab.research.google.com/github/james-monahan/Code-school-notebooks/blob/main/Week-4-python-sql/Colab_modulate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/My\ Drive/*.py
# Out:
# '/content/drive/My Drive/math_functions.py'

# %%
#!cat '/content/drive/My Drive/math_functions.py'

# %%
sys.path.append('/content/drive/My Drive')

# %%
sys.path
# Out:
# ['',
#  '/env/python',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content/drive/My Drive']

# %%
import math_functions as mf

# %%
help(math_functions)
# Out:
# Help on module math_functions:
#
# NAME
#     math_functions - math_functions.ipynb
#
# DESCRIPTION
#     Automatically generated by Colaboratory.
#
#     Original file is located at
#         https://colab.research.google.com/drive/1y-LhznFmQ0-JA29V2fgXMM7VGhY6H3g1
#
# FUNCTIONS
#     abs_val(num)
#         # Cube of a number: Create a function that returns the cube of a number.
#
#     average(nums)
#         # Mode of a list of numbers: Create a function that returns the mode of a list of numbers.
#
#     cube(num)
#         #â€¯Square of a number: Create a function that returns the square of a number.
#
#     factorial(num)
#         # Absolute value: Create a function that returns the absolute value of a number.
#
#     fibo(seq=30)
#         # Prime number less than x : Create a function that takes a number and returns all the prime numbers that are less than it.
#
#     find_max(nums)
# ...

# %% [markdown]
# square root of 42 + 3 to the cube +
# factorial of 5 /divide by the absolute value
# of (-15) - maximum of a list of int (to be created)- the
# sum of prime numbers less than 100 * minimum
# of the list + 4 to the power of the mode of the list

# %%
list_of_int = [5,10,25,86,100]

# %%
mf.sq_root(42)  +  mf.cube(3)  +  (mf.factorial(5)/mf.abs_val(-15))  -  mf.find_max(list_of_int)  -  sum(mf.find_primes(100))  * mf.find_min(list_of_int)  +  mf.num_to_power(4, mf.mode(list_of_int))
# Out:
# 1125899906837265.5
